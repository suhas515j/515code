# %%
import re
class Gym:
    d={}
    l1=[]
    def __init__(self,Name):
        self.name=Name
     
    def start_cmd(self):
        while(True):
            
            print("..")
            print("**************************************************************************************************")
            print("1.Create member")
            print("2. View Member")
            print("3. Update member")
            print("4. Delete member")
            print("5. Create default regm")
            print("6. View regm")
            print("7. Delete regm")
            print("8. Update regm")
            print("x. Exit")
            ans=input("Please enter Your Choice: ")
            print("**************************************************************************************************")
            if(ans=="1"):
                Gym.create_member(self)
            if(ans=="2"):
                Gym.view_member(self)
            if(ans=="3"):
                Gym.update_member(self)
            if(ans=="4"):
                Gym.delete_member(self)
            if(ans=="5"):
                Gym.create_regm(self)
            if(ans=="6"):
                Gym.view_regm(self)
            if(ans=="7"):
                Gym.delete_regm(self)
            if(ans=="8"):
                Gym.update_regm(self)
            if(ans=="x"):
                break
        print("Thank you")
        
        
    
    def create_member(self):
        d={}
        lname=[]
        while(True):
            name=input("Enter Your Name : ")
            if(name not in lname):
                lname.append(name)
                break
            else:
                print("Name already registered")
        age=input("Enter your Age : ")
        
        while(True):
            gender=input("Enter your Gender")
            if(gender in ['male','female']):
                break
            else:
                print("Please enter valid input")
                
                
        
        while(True):
            mobileNumber=input("Enter mobile number :")
            regex = r'\b[0-9]{10}\b'
            if re.fullmatch(regex, mobileNumber):
                 break
            else:
                print("Enter valid mobile number")
        
    
        while(True):
            email=input("Enter your Email")
            regex = r'\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Z|a-z]{2,}\b'
            if re.fullmatch(regex, email):
                 break
            else:
                print("Enter valid mail")
        bmi=input("enter bmi")
        while(True):
            membership_duration=input("Enter membership duration : ")
            if(int(membership_duration)%3==0 and int(membership_duration)<=12):
                break
            else:
                print("Please Enter in multiples of 3")
        d["name"]=name
        d["age"]=age
        d["gender"]=gender
        d["mobileNumber"]=mobileNumber
        d["email"]=email
        d["bmi"]=bmi
        d["membership_duration"]=membership_duration
        d["regm"]={}
        Gym.l1.append(d)
    
    def view_member(self):
        while(True):
            cno=input("Enter mobile number to search :")
            regex = r'\b[0-9]{10}\b'
            if re.fullmatch(regex, cno):
                 break
            else:
                print("Enter valid mobile number")
        
        for i in Gym.l1:
            if i["mobileNumber"]==cno:
                print("..")
                print("*********************************MEMBER DETAILS****************************************")
                print("Name is:",i["name"])
                print("Age is:",i["age"])
                print("gender is:",i["gender"])
                print("Mobile number is: ",i["mobileNumber"])
                print("Email : ",i["email"])
                print("BMI is :",i["bmi"])
                print("Member duration",i["membership_duration"])
                print("..")
                print("**************************************************************************************************")
                return
        else:
            print("Not found")
    
    def update_member(self):
        att=input("Enter your name:")
        while(True):
            val=input("Enter how many months you want to extend")
            if(int(val)%3==0):
                break
            else:
                print("Please Enter in multiples of 3")
        for i in Gym.l1:
            if i["name"]==att:
                a=int(i["membership_duration"])+int(val)
                i["membership_duration"]=str(a)
                print("..")
                print("**************************************************************************************************")
                print("Updated sucessfully!")
                return
        print("Name not found please register")
    
    def delete_member(self):
        name=input("Enter name of member: ")
        for i in range(len(Gym.l1)):
            if name==Gym.l1[i]["name"]:
                Gym.l1[i]={}
                print("..")
                print("**************************************************************************************************")
                print("Sucessfully deleted")
                return
        else:
            print("Name not registered")
        
    
    def create_regm(self):
        name=input("Enter Name :")
        for i in Gym.l1:
            if(name==i["name"]):
                if(int(i["bmi"])<=18.5):
                    i['regm']={"Mon":"Chest","Tue":"Biceps","Wed":"Rest","Thu":"Back","Fri":"Triceps","Sat":"Rest","Sun":"Rest"}
                    print("Regm updated sucessfully for 18.5 bmi")
                    return
                elif(int(i["bmi"])<=25):
                    i['regm']={"Mon":"Chest","Tue":"Biceps","Wed":"Cadio/Abs","Thu":"Back","Fri":"Triceps","Sat":"Legs","Sun":"Rest"}
                    print("Regm updated sucessfully for 25 bmi")
                    return
                elif(int(i["bmi"])<=30):
                    i['regm']={"Mon":"Chest","Tue":"Biceps","Wed":"Cadio/Abs","Thu":"Back","Fri":"Triceps","Sat":"Legs","Sun":"Cardio"}
                    print("Regm updated sucessfully for 30 bmi")
                    return
                elif(int(i["bmi"])>30):
                    i['regm']={"Mon":"Chest","Tue":"Biceps","Wed":"Cadio","Thu":"Back","Fri":"Triceps","Sat":"Cardio","Sun":"Cardio"}
                    print("Regm updated sucessfully for above 30 bmi")
                    return
                else:
                    print("invalid bmi")
                    return
        print("Name not Regestered")
                    
    
    def view_regm(self):
        name=input("Enter Name :")
        for i in Gym.l1:
            if(name==i["name"]):
                if(i["regm"]=={}):
                    print("Your regm is empty")
                    return
                print("--------------")
                print("Your regm is as follows::")
                print("Monday :",i["regm"]["Mon"] )
                print("Tuesday :",i["regm"]["Tue"] )
                print("Wednesday :",i["regm"]["Wed"] )
                print("Thurday :",i["regm"]["Thu"] )
                print("Firday :",i["regm"]["Fri"] )
                print("Saturday :",i["regm"]["Sat"] )
                print("Sunday :",i["regm"]["Sun"] )
                print("..")
                print("**************************************************************************************************")
                return
        print("Invalid Name")
    
    
    def delete_regm(self):
        name=input("Enter name of member: ")
        for i in range(len(Gym.l1)):
            if name==Gym.l1[i]["name"]:
                Gym.l1[i]["regm"]={}
                print("Sucessfully deleted regm")
                print("..")
                print("**************************************************************************************************")
                return
        else:
            print("Name not registered")
    
    
    def update_regm(self):
        name=input("Enter name of member")
        while(True):
            day= input("Enter which day with only 3 letters like Mon with captial first letter")
            if day in ["Mon","Tue","Wed","Thu","Fri","Sat","Sun"]:
                break
            else:
                print("Invalid day")
        exer=input("Enter type of excersice")
         
        for i in range(len(Gym.l1)):
            if name==Gym.l1[i]["name"]:
                if(Gym.l1[i]["regm"]=={}):
                    print("regm not generated please generate regm")
                    return
                Gym.l1[i]["regm"][day]=exer
                print("Sucessfully updated for the Day ",day)
                print("..")
                print("**************************************************************************************************")
                return
        else:
            print("Name not found")
                

                
class Member(Gym):
    def _init__(self):
        Gym.__init__(self, gymName)
        
    def myRegimen(self):
        for i in Gym.l1:
            if(self.name==i["name"]):
                if(i["regm"]=={}):
                    print("Hi ",self.name," Your regm is empty")
                    return
                print("--------------")
                print("Hi ",self.name," regm is as follows::")
                print("Monday :",i["regm"]["Mon"] )
                print("Tuesday :",i["regm"]["Tue"] )
                print("Wednesday :",i["regm"]["Wed"] )
                print("Thurday :",i["regm"]["Thu"] )
                print("Firday :",i["regm"]["Fri"] )
                print("Saturday :",i["regm"]["Sat"] )
                print("Sunday :",i["regm"]["Sun"] )


    def myprofile(self):
        print(self.name)
        for i in Gym.l1:
            if i["name"]==self.name:
                print("..")
                print("**************************************************************************************************")
                
                print("Name is:",i["name"])
                print("Age is:",i["age"])
                print("gender is:",i["gender"])
                print("Mobile number is: ",i["mobileNumber"])
                print("Email : ",i["email"])
                print("BMI is :",i["bmi"])
                print("Membership duration : ",i["membership_duration"])
                return
        else:
            print("Not found")

# %%
superuser=Gym('superuser')

# %%
superuser.start_cmd()
# Out:
# ..
# **************************************************************************************************
# 1.Create member
# 2. View Member
# 3. Update member
# 4. Delete member
# 5. Create default regm
# 6. View regm
# 7. Delete regm
# 8. Update regm
# x. Exit
# Please enter Your Choice: 1
# **************************************************************************************************
# Enter Your Name : suhas
# Enter your Age : 21
# Enter your Genderkaodk
# Please enter valid input
# Enter your Gendermale
# Enter mobile number :844
# Enter valid mobile number
# Enter mobile number :8073532059
# Enter your Emailsadu
# Enter valid mail
# Enter your Emailsuhasj515@gmail.com
# enter bmi26
# Enter membership duration : 16
# Please Enter in multiples of 3
# Enter membership duration : 5
# Please Enter in multiples of 3
# Enter membership duration : 3
# ..
# **************************************************************************************************
# 1.Create member
# ...

# %%
suhas=Member('suhas')

# %%
suhas.myprofile()
# Out:
# suhas
# ..
# **************************************************************************************************
# Name is: suhas
# Age is: 21
# gender is: male
# Mobile number is:  8073532059
# Email :  suhasj515@gmail.com
# BMI is : 26
# Membership duration :  9

# %%
suhas.myRegimen()
# Out:
# --------------
# Hi  suhas  regm is as follows::
# Monday : Chest
# Tuesday : Biceps
# Wednesday : Cadio/Abs
# Thurday : Back
# Firday : Triceps
# Saturday : Legs
# Sunday : Cardio
